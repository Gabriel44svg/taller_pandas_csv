# %% [markdown]
# # Reto por equipos: DATA DETECTIVE
#
# **Dataset:** `data/reto_detective.csv` — usuarios de una app de delivery.
#
# Este dataset tiene "trampas" a propósito: duplicados, valores imposibles,
# inconsistencias de texto, valores faltantes y outliers reales. Su trabajo
# es encontrarlas y decidir qué hacer con cada una.
#
# ## Entregable (llenar al final del notebook)
# 1. Una pregunta.
# 2. Una hipótesis.
# 3. Una estadística.
# 4. Una gráfica.
# 5. Un hallazgo.
# 6. Una anomalía.
# 7. Una conclusión.
#
# > No gana quien haga más gráficas. Gana quien encuentre una historia
# > interesante y pueda demostrarla.

# %%
# --- Setup: correr esta celda primero ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('../data/reto_detective.csv')
df.head()

# %% [markdown]
# ## Paso 1 — Conocer la escena
# `df.shape`, `df.info()`, `df.describe()`, `df.isnull().sum()`

# %%
# TODO: exploren el dataset
# ¿Cuantas filas y columnas hay?
# ¿Que tipo de dato tiene cada columna?
# ¿Cuantos valores faltan por columna?

# %% [markdown]
# ## Paso 2 — Buscar trampas de calidad de datos
# Pistas: revisen duplicados, valores imposibles (edades, calificaciones)
# e inconsistencias de texto en columnas categóricas (ej. mayúsculas,
# espacios, nombres distintos para el mismo valor).

# %%
# TODO: ¿hay filas duplicadas? ¿cuantas?
# df.duplicated().sum()

# TODO: revisen los valores unicos de las columnas de texto
# df['ciudad'].unique()
# df['plataforma'].unique()

# TODO: busquen valores fuera de rango logico (edad negativa, calificacion > 5, etc.)

# %% [markdown]
# ## Paso 3 — Distribuciones
# Elijan al menos 2 variables numéricas y grafiquen su distribución
# (histograma o boxplot).

# %%
# TODO: histograma y/o boxplot de las variables que elijan

# %% [markdown]
# ## Paso 4 — Outliers
# Apliquen el método del IQR a alguna variable numérica. Decidan: ¿es un
# error o un caso real?

# %%
# TODO: calculen Q1, Q3, IQR y los limites inferior/superior
# Q1 = df['columna'].quantile(0.25)
# Q3 = df['columna'].quantile(0.75)
# IQR = Q3 - Q1

# %% [markdown]
# ## Paso 5 — Relaciones
# Elijan dos variables numéricas y calculen su correlación. Hagan un
# scatterplot.

# %%
# TODO: correlacion entre dos variables
# df['col1'].corr(df['col2'])

# TODO: scatterplot
# plt.scatter(df['col1'], df['col2'])
# plt.show()

# %% [markdown]
# ## Paso 6 — Comparar grupos
# Comparen `gasto_mensual` (o `tiempo_entrega_min`) entre dos categorías
# (ej. plataforma, ciudad). Un boxplot agrupado funciona bien.

# %%
# TODO: boxplot agrupado por categoria
# df.boxplot(column='variable_numerica', by='variable_categorica')
# plt.show()

# %% [markdown]
# ## Entregable final
#
# Completen cada bloque con su respuesta.

# %% [markdown]
# ### Pregunta
# _(¿Qué queremos descubrir?)_
#
# ### Hipótesis
# _(¿Qué creemos que ocurre?)_
#
# ### Evidencia
# _(¿Qué muestran los datos? Estadística + gráfica)_
#
# ### Hallazgo / Anomalía
# _(¿Qué encontraron que no esperaban?)_
#
# ### Conclusión
# _(¿Qué podemos afirmar?)_
#
# ### Limitación
# _(¿Qué todavía NO podemos afirmar?)_
